# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit-Padye/ZOMATO-RESTAURANT-CLUSTERING-AND-SENTIMENT-ANALYSIS/blob/main/Amit_Padye_ZOMATO_RESTAURANT_CLUSTERING_AND_SENTIMENT_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Zomato is an Indian restaurant aggregator and food delivery start-up founded by Deepinder Goyal and Pankaj Chaddah in 2008. Zomato provides information, menus and user-reviews of restaurants, and also has food delivery options from partner restaurants in select cities.
#
# India is quite famous for its diverse multi cuisine available in a large number of restaurants and hotel resorts, which is reminiscent of unity in diversity. Restaurant business in India is always evolving. More Indians are warming up to the idea of eating restaurant food whether by dining outside or getting food delivered. The growing number of restaurants in every state of India has been a motivation to inspect the data to get some insights, interesting facts and figures about the Indian food industry in each city. So, this project focuses on analysing the Zomato restaurant data for each city in India.
#
# The Project focuses on Customers and Company, you have  to analyze the sentiments of the reviews given by the customer in the data and made some useful conclusion in the form of Visualizations. Also, cluster the zomato restaurants into different segments. The data is vizualized as it becomes easy to analyse data at instant. The Analysis also solve some of the business cases that can directly help the customers finding the Best restaurant in their locality and for the company to grow up and work on the fields they are currently lagging in.
#
# This could help in clustering the restaurants into segments. Also the data has valuable information around cuisine and costing which can be used in cost vs. benefit analysis
#
# Data could be used for sentiment analysis. Also the metadata of reviewers can be used for identifying the critics in the industry.

# %% [markdown]
# # **Attribute Information**

# %% [markdown]
# ## **Zomato Restaurant names and Metadata**
# Use this dataset for clustering part

# %% [markdown]
# 1. Name : Name of Restaurants
#
# 2. Links : URL Links of Restaurants
#
# 3. Cost : Per person estimated Cost of dining
#
# 4. Collection : Tagging of Restaurants w.r.t. Zomato categories
#
# 5. Cuisines : Cuisines served by Restaurants
#
# 6. Timings : Restaurant Timings

# %% [markdown]
# ## **Zomato Restaurant reviews**
# Merge this dataset with Names and Matadata and then use for sentiment analysis part

# %% [markdown]
# 1. Restaurant : Name of the Restaurant
#
# 2. Reviewer : Name of the Reviewer
#
# 3. Review : Review Text
#
# 4. Rating : Rating Provided by Reviewer
#
# 5. MetaData : Reviewer Metadata - No. of Reviews and followers
#
# 6. Time: Date and Time of Review
#
# 7. Pictures : No. of pictures posted with review

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('/content/drive/MyDrive/Zomato Restaurant reviews.csv')
df2=pd.read_csv('/content/drive/MyDrive/Zomato Restaurant names and Metadata.csv')

# %%
df1.head()
# Out:
#         Restaurant              Reviewer  ...             Time Pictures
# 0  Beyond Flavours     Rusha Chakraborty  ...  5/25/2019 15:54        0
# 1  Beyond Flavours  Anusha Tirumalaneedi  ...  5/25/2019 14:20        0
# 2  Beyond Flavours       Ashok Shekhawat  ...  5/24/2019 22:54        0
# 3  Beyond Flavours        Swapnil Sarkar  ...  5/24/2019 22:11        0
# 4  Beyond Flavours                Dileep  ...  5/24/2019 21:37        0
#
# [5 rows x 7 columns]

# %%
df1.shape
# Out:
# (10000, 7)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Restaurant  10000 non-null  object
#  1   Reviewer    9962 non-null   object
#  2   Review      9955 non-null   object
#  3   Rating      9962 non-null   object
#  4   Metadata    9962 non-null   object
#  5   Time        9962 non-null   object
#  6   Pictures    10000 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 547.0+ KB

# %%
df1.describe(include='all')
# Out:
#                 Restaurant Reviewer  ...             Time      Pictures
# count                10000     9962  ...             9962  10000.000000
# unique                 100     7446  ...             9782           NaN
# top     Hunger Maggi Point   Ankita  ...  7/29/2018 20:34           NaN
# freq                   100       13  ...                3           NaN
# mean                   NaN      NaN  ...              NaN      0.748600
# std                    NaN      NaN  ...              NaN      2.570381
# min                    NaN      NaN  ...              NaN      0.000000
# 25%                    NaN      NaN  ...              NaN      0.000000
# 50%                    NaN      NaN  ...              NaN      0.000000
# 75%                    NaN      NaN  ...              NaN      0.000000
# max                    NaN      NaN  ...              NaN     64.000000
#
# [11 rows x 7 columns]

# %%
df2.head()
# Out:
#                              Name  ...                                            Timings
# 0                 Beyond Flavours  ...      12noon to 3:30pm, 6:30pm to 11:30pm (Mon-Sun)
# 1                        Paradise  ...                                     11 AM to 11 PM
# 2                        Flechazo  ...              11:30 AM to 4:30 PM, 6:30 PM to 11 PM
# 3  Shah Ghouse Hotel & Restaurant  ...                                    12 Noon to 2 AM
# 4      Over The Moon Brew Company  ...  12noon to 11pm (Mon, Tue, Wed, Thu, Sun), 12no...
#
# [5 rows x 6 columns]

# %%
df1.shape,df2.shape
# Out:
# ((10000, 7), (105, 6))

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         105 non-null    object
#  1   Links        105 non-null    object
#  2   Cost         105 non-null    object
#  3   Collections  51 non-null     object
#  4   Cuisines     105 non-null    object
#  5   Timings      104 non-null    object
# dtypes: object(6)
# memory usage: 5.0+ KB

# %%
df2.describe(include='all')
# Out:
#                 Name  ...         Timings
# count            105  ...             104
# unique           105  ...              77
# top     Arena Eleven  ...  11 AM to 11 PM
# freq               1  ...               6
#
# [4 rows x 6 columns]

# %%
df=df1.merge(df2, left_on='Restaurant', right_on='Name').drop('Name',axis=1)

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.head()
# Out:
#         Restaurant  ...                                        Timings
# 0  Beyond Flavours  ...  12noon to 3:30pm, 6:30pm to 11:30pm (Mon-Sun)
# 1  Beyond Flavours  ...  12noon to 3:30pm, 6:30pm to 11:30pm (Mon-Sun)
# 2  Beyond Flavours  ...  12noon to 3:30pm, 6:30pm to 11:30pm (Mon-Sun)
# 3  Beyond Flavours  ...  12noon to 3:30pm, 6:30pm to 11:30pm (Mon-Sun)
# 4  Beyond Flavours  ...  12noon to 3:30pm, 6:30pm to 11:30pm (Mon-Sun)
#
# [5 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Restaurant        0
# Reviewer         38
# Review           45
# Rating           38
# Metadata         38
# Time             38
# Pictures          0
# Links             0
# Cost              0
# Collections    5000
# Cuisines          0
# Timings         100
# dtype: int64

# %% [markdown]
# ###Restaurant

# %%
df['Restaurant'].nunique()
# Out:
# 100

# %% [markdown]
# **100 Restaurant information is given**

# %%
df['Restaurant'].value_counts()
# Out:
# Hunger Maggi Point                  100
# Pista House                         100
# Being Hungry                        100
# KFC                                 100
# Hyderabadi Daawat                   100
#                                    ...
# Delhi-39                            100
# La La Land - Bar & Kitchen          100
# T Grill                             100
# Feast - Sheraton Hyderabad Hotel    100
# Mohammedia Shawarma                 100
# Name: Restaurant, Length: 100, dtype: int64

# %% [markdown]
# **Each restaurant has 100 review 100*100=10000**

# %% [markdown]
# ###Review

# %%
df[(df['Review'].isnull())  & df['Rating'].isnull()].shape
# Out:
# (38, 12)

# %%
df[(df['Review'].isnull())  & df['Rating'].notnull()].shape
# Out:
# (7, 12)

# %%
df[(df['Review'].isnull())  & df['Rating'].notnull()]
# Out:
#               Restaurant  ...                            Timings
# 2360                Amul  ...                      10 AM to 5 AM
# 5799        Being Hungry  ...  12 Noon to 3 PM, 7 PM to 11:30 PM
# 6449     Hyderabad Chefs  ...                12 Noon to 10:30 PM
# 6489     Hyderabad Chefs  ...                12 Noon to 10:30 PM
# 7954        Olive Garden  ...  12 Noon to 3:30 PM, 7 PM to 11 PM
# 8228  Al Saba Restaurant  ...                   6 AM to 11:30 PM
# 8844      Domino's Pizza  ...                     11 AM to 11 PM
#
# [7 rows x 12 columns]

# %% [markdown]
# ###Rating

# %%
df['Rating'].unique()
# Out:
# array(['5', '4', '1', '3', '2', '3.5', '4.5', '2.5', '1.5', 'Like', nan],
#       dtype=object)

# %%
df['Rating'].value_counts()
# Out:
# 5       3832
# 4       2373
# 1       1735
# 3       1193
# 2        684
# 4.5       69
# 3.5       47
# 2.5       19
# 1.5        9
# Like       1
# Name: Rating, dtype: int64

# %%
sns.countplot(df['Rating'])

# %%
df_like=df[df['Rating']=='Like']

# %%
df_like['Rating']='5'

# %%
df=df[df['Rating']!='Like']

# %%
df.shape
# Out:
# (9999, 12)

# %%
df = pd.concat([df, df_like])
#df.reset_index()

# %%
df.shape
# Out:
# (10000, 12)

# %%
#changing data type of rating
df['Rating']=df['Rating'].astype(float)

# %%
df[df['Rating'].isnull()].head()
# Out:
#                Restaurant  ...          Timings
# 8777  American Wild Wings  ...  12 Noon to 4 AM
# 8778  American Wild Wings  ...  12 Noon to 4 AM
# 8779  American Wild Wings  ...  12 Noon to 4 AM
# 8780  American Wild Wings  ...  12 Noon to 4 AM
# 8781  American Wild Wings  ...  12 Noon to 4 AM
#
# [5 rows x 12 columns]

# %%
df[df['Rating'].isnull()]['Restaurant'].nunique()
# Out:
# 2

# %% [markdown]
# **There are duplicate in dataet and as rating and text review is not available so we con drop this rows.**

# %%
df=df.drop_duplicates(subset=df.columns, keep=False)

# %%
df.shape  #38 duplicates
# Out:
# (9962, 12)

# %% [markdown]
# **38 duplicates present**

# %% [markdown]
# ###Metadata

# %%
df['Metadata'].nunique()
# Out:
# 2477

# %%
df['Metadata'].value_counts()
# Out:
# 1 Review                        919
# 1 Review , 1 Follower           750
# 2 Reviews , 1 Follower          337
# 2 Reviews                       262
# 1 Review , 2 Followers          227
#                                ...
# 2 Reviews , 332 Followers         1
# 67 Reviews , 225 Followers        1
# 51 Reviews , 99 Followers         1
# 25 Reviews , 1290 Followers       1
# 104 Reviews , 2833 Followers      1
# Name: Metadata, Length: 2477, dtype: int64

# %%
df1[['Reviews_Given','Followers']] = df['Metadata'].str.split(',',expand=True)

# %%
df1.head()
# Out:
#         Restaurant              Reviewer  ... Reviews_Given     Followers
# 0  Beyond Flavours     Rusha Chakraborty  ...     1 Review    2 Followers
# 1  Beyond Flavours  Anusha Tirumalaneedi  ...    3 Reviews    2 Followers
# 2  Beyond Flavours       Ashok Shekhawat  ...    2 Reviews    3 Followers
# 3  Beyond Flavours        Swapnil Sarkar  ...     1 Review     1 Follower
# 4  Beyond Flavours                Dileep  ...    3 Reviews    2 Followers
#
# [5 rows x 9 columns]

# %% [markdown]
# ###Cost

# %%
df['Cost'] = df['Cost'].str.replace(',', '')

# %%
df['Cost'] = df['Cost'].astype(float)

# %%
sns.distplot(df['Cost'])

# %% [markdown]
# ###Collections

# %%
df[df['Collections'].isnull()]['Restaurant'].nunique()
# Out:
# 50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9962 entries, 0 to 7601
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Restaurant   9962 non-null   object
#  1   Reviewer     9962 non-null   object
#  2   Review       9955 non-null   object
#  3   Rating       9962 non-null   float64
#  4   Metadata     9962 non-null   object
#  5   Time         9962 non-null   object
#  6   Pictures     9962 non-null   int64
#  7   Links        9962 non-null   object
#  8   Cost         9962 non-null   float64
#  9   Collections  4962 non-null   object
#  10  Cuisines     9962 non-null   object
#  11  Timings      9862 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 1.3+ MB

# %% [markdown]
# ###Cuisines

# %%
cuisines = df2['Cuisines']
cuisines = cuisines.apply(lambda x : x.lower())

# %%
from collections import Counter

# %%
all_cuisines = ', '.join(i for i in cuisines.tolist())
print(all_cuisines)
all_cuisines = Counter(all_cuisines.split(', '))
print(all_cuisines)
all_cuisines = pd.DataFrame.from_dict(all_cuisines, orient='index', dtype='int')
all_cuisines.columns = ['No Of Restaurents']
all_cuisines.sort_values(by='No Of Restaurents', ascending=False, inplace=True)
cusines=pd.DataFrame(all_cuisines[0:10])
cusines
# Out:
# chinese, continental, kebab, european, south indian, north indian, biryani, north indian, chinese, asian, mediterranean, north indian, desserts, biryani, north indian, chinese, seafood, beverages, asian, continental, north indian, chinese, mediterranean, seafood, goan, north indian, continental, asian, healthy food, north indian, continental, south indian, lebanese, american, chinese, north indian, kebab, south indian, ice cream, desserts, street food, north indian, fast food, mediterranean, north indian, kebab, bbq, continental, american, chinese, north indian, italian, finger food, european, mediterranean, north indian, burger, fast food, north indian, chinese, north indian, north indian, chinese, continental, north indian, chinese, biryani, north indian, north indian, japanese, italian, salad, sushi, american, ice cream, desserts, north indian, chinese, continental, continental, mexican, italian, north indian, chinese, salad, north indian, mediterranean, european, mughlai, biryani, fast food, andhra, south indian, north indian, bakery, north indian, mughlai, juices, chinese, arabian, north indian, chinese, north indian, fast food, italian, north indian, south indian, asian, north indian, chinese, biryani, biryani, south indian, north indian, chinese, andhra, andhra, biryani, hyderabadi, north indian, north indian, continental, italian, asian, cafe, continental, desserts, european, italian, continental, spanish, bakery, fast food, desserts, cafe, desserts, fast food, american, wraps, desserts, finger food, north indian, kebab, chinese, chinese, biryani, andhra, north indian, andhra, north indian, chinese, chinese, thai, indonesian, asian, south indian, north indian, chinese, south indian, north indian, chinese, north indian, continental, biryani, north indian, chinese, north indian, biryani, chinese, chinese, continental, italian, asian, cafe, bakery, modern indian, asian, continental, italian, north indian, chinese, desserts, beverages, bakery, desserts, fast food, north indian, continental, chinese, italian, kebab, continental, italian, north indian, north indian, chinese, fast food, chinese, asian, momos, north indian, chinese, north indian, chinese, japanese, sushi, north indian, chinese, mughlai, biryani, north indian, hyderabadi, north indian, continental, italian, bbq, asian, modern indian, asian, thai, chinese, sushi, momos, north indian, mughlai, beverages, bakery, desserts, cafe, fast food, beverages, fast food, biryani, desserts, north indian, south indian, bakery, italian, north indian, chinese, salad, north indian, mughlai, north indian, chinese, continental, biryani, north indian, burger, kebab, north indian, chinese, north indian, chinese, seafood, biryani, hyderabadi, burger, american, north indian, andhra, biryani, chinese, momos, cafe, desserts, american, fast food, salad, burger, fast food, pizza, street food, arabian, continental, north indian, italian, continental, asian, continental, italian, north indian, chinese, asian, north eastern, momos, desserts, cafe, beverages, burger, fast food, north indian, chinese, hyderabadi, chinese, mughlai, asian, sushi, north indian, chinese, seafood, fast food, salad, bakery, mithai, north indian, biryani, chinese, fast food, thai, asian, chinese, malaysian
# Counter({'north indian': 61, 'chinese': 43, 'continental': 21, 'biryani': 16, 'asian': 15, 'fast food': 15, 'italian': 14, 'desserts': 13, 'south indian': 9, 'bakery': 7, 'kebab': 6, 'american': 6, 'mughlai': 6, 'andhra': 6, 'cafe': 6, 'mediterranean': 5, 'beverages': 5, 'burger': 5, 'salad': 5, 'european': 4, 'seafood': 4, 'sushi': 4, 'hyderabadi': 4, 'momos': 4, 'thai': 3, 'ice cream': 2, 'street food': 2, 'bbq': 2, 'finger food': 2, 'japanese': 2, 'arabian': 2, 'modern indian': 2, 'goan': 1, 'healthy food': 1, 'lebanese': 1, 'mexican': 1, 'juices': 1, 'spanish': 1, 'wraps': 1, 'indonesian': 1, 'pizza': 1, 'north eastern': 1, 'mithai': 1, 'malaysian': 1})
#               No Of Restaurents
# north indian                 61
# chinese                      43
# continental                  21
# biryani                      16
# fast food                    15
# asian                        15
# italian                      14
# desserts                     13
# south indian                  9
# bakery                        7

# %%
3 in [1, 2, 3]
# Out:
# True

# %% [markdown]
# ###Sentiment Analysis

# %%
sent_df=df.loc[:,['Review','Rating']]

# %%
#drop review having nan
sent_df=sent_df.dropna()

# %%
sent_df.head()
# Out:
#                                               Review  Rating
# 0  The ambience was good, food was quite good . h...     5.0
# 1  Ambience is too good for a pleasant evening. S...     5.0
# 2  A must try.. great food great ambience. Thnx f...     5.0
# 3  Soumen das and Arun was a great guy. Only beca...     5.0
# 4  Food is good.we ordered Kodi drumsticks and ba...     5.0

# %%
sent_df.set_index("Review", inplace = True)

# %%
a=sent_df[sent_df['Rating']==3]

# %%
a.head()
# Out:
#                                                     Rating
# Review
# Short review: Decent breads and starters, bad S...     3.0
# The reason for giving only a 3 star is because ...     3.0
# We went for lunch buffet yesterday and took a c...     3.0
# We happened to go to this place on last sunday ...     3.0
# I have been to this place twice and had 2 diffe...     3.0

# %%
a=sent_df[sent_df['Rating']==3.5]

# %%
a.head(10)
# Out:
#                                                     Rating
# Review
# It's too crowded with delivery executives all t...     3.5
# Nice pocket friendly place. Burgers and sandwic...     3.5
# Well, all the time I have ordered here it has b...     3.5
# chocolate truffle is great here!\nFerrerro roch...     3.5
# KS bakers , known for its food in bakery items....     3.5
# Ordered chicken and cheese burger and egg puff ...     3.5
# The burger was just decent but complete value f...     3.5
# It's a good option but the bread they use for h...     3.5
# Neat and clean ambiance. Small place but it's w...     3.5
# Komatose on a Sunday night is the perfect place...     3.5

# %%
sent_df['Rating'].value_counts()
# Out:
# 5.0    3827
# 4.0    2373
# 1.0    1735
# 3.0    1192
# 2.0     684
# 4.5      69
# 3.5      47
# 2.5      19
# 1.5       9
# Name: Rating, dtype: int64

# %%
sent_df.isnull().sum()
# Out:
# Rating    0
# dtype: int64

# %%
def sentiment(rating):
  if rating>=3.5:
    return 1 # positive sentiment
  else:
    return 0

# %%
sent_df['sentiment']=sent_df['Rating'].apply(lambda x:sentiment(x))

# %%
sns.countplot(sent_df['sentiment'])

# %%
sent_df.reset_index(inplace=True)

# %%
sent_df
# Out:
#                                                  Review  Rating  sentiment
# 0     The ambience was good, food was quite good . h...     5.0          1
# 1     Ambience is too good for a pleasant evening. S...     5.0          1
# 2     A must try.. great food great ambience. Thnx f...     5.0          1
# 3     Soumen das and Arun was a great guy. Only beca...     5.0          1
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0          1
# ...                                                 ...     ...        ...
# 9950  This place has never disappointed us.. The foo...     4.5          1
# 9951  Bad rating is mainly because of "Chicken Bone ...     1.5          0
# 9952  I personally love and prefer Chinese Food. Had...     4.0          1
# 9953  Checked in here to try some delicious chinese ...     3.5          1
# 9954  One of the best pizzas to try. It served with ...     5.0          1
#
# [9955 rows x 3 columns]

# %% [markdown]
# ###Remove Emoji

# %%
#!/usr/bin/env python
import re

# %%
def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)

# %%
sent_df['Review']=sent_df['Review'].apply(lambda x:deEmojify(x))

# %%
a=sent_df[sent_df['Rating']==3.5]
a.set_index("Review", inplace = True)

# %%
#check weather emoji removed or not
a.head(10)
# Out:
#                                                     Rating  sentiment
# Review
# It's too crowded with delivery executives all t...     3.5          1
# Nice pocket friendly place. Burgers and sandwic...     3.5          1
# Well, all the time I have ordered here it has b...     3.5          1
# chocolate truffle is great here!\nFerrerro roch...     3.5          1
# KS bakers , known for its food in bakery items....     3.5          1
# Ordered chicken and cheese burger and egg puff ...     3.5          1
# The burger was just decent but complete value f...     3.5          1
# It's a good option but the bread they use for h...     3.5          1
# Neat and clean ambiance. Small place but it's w...     3.5          1
# Komatose on a Sunday night is the perfect place...     3.5          1

# %% [markdown]
# ###Remove Ratings and \n from review

# %%
tweet="4/5\nAmbience: 3/5 Nothing extra ordinary.\nValue for money: 4.5/5"

# %%
tweet=re.sub(r'([0.-9.]+/+[0.-9.]+)','',tweet)

# %%
tweet
# Out:
# '\nAmbience:  Nothing extra ordinary.\nValue for money: '

# %%
re.sub(r'(\n+)','',tweet)
# Out:
# 'Ambience:  Nothing extra ordinary.Value for money: '

# %%
def remove_rating(rating):
  rating=re.sub(r'([0.-9.]+/+[0.-9.]+)','',rating)
  rating=re.sub(r'(\n+)','',rating)
  return rating

# %%
sent_df['Review']=sent_df['Review'].apply(lambda x:remove_rating(x))

# %%
a=sent_df[sent_df['Rating']==3.5]
a.set_index("Review", inplace = True)

# %%
a.head(10)
# Out:
#                                                     Rating  sentiment
# Review
# It's too crowded with delivery executives all t...     3.5          1
# Nice pocket friendly place. Burgers and sandwic...     3.5          1
# Well, all the time I have ordered here it has b...     3.5          1
# chocolate truffle is great here!Ferrerro rocher...     3.5          1
# KS bakers , known for its food in bakery items....     3.5          1
# Ordered chicken and cheese burger and egg puff ...     3.5          1
# The burger was just decent but complete value f...     3.5          1
# It's a good option but the bread they use for h...     3.5          1
# Neat and clean ambiance. Small place but it's w...     3.5          1
# Komatose on a Sunday night is the perfect place...     3.5          1

# %% [markdown]
# ###Lower case conversion

# %%
sent_df['Review']=sent_df['Review'].apply(lambda x:x.lower())

# %%
sent_df.head()
# Out:
#                                               Review  Rating  sentiment
# 0  the ambience was good, food was quite good . h...     5.0          1
# 1  ambience is too good for a pleasant evening. s...     5.0          1
# 2  a must try.. great food great ambience. thnx f...     5.0          1
# 3  soumen das and arun was a great guy. only beca...     5.0          1
# 4  food is good.we ordered kodi drumsticks and ba...     5.0          1

# %% [markdown]
# ###convert short form

# %%
# !pip install contractions
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.7/dist-packages (0.0.52)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.7/dist-packages (from contractions) (0.0.21)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (0.3.0)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (1.4.2)

# %%
import contractions

# %%
sent_df['Review']=sent_df['Review'].apply(lambda x:contractions.fix(x))

# %%
a=sent_df[sent_df['Rating']==3.5]
a.set_index("Review", inplace = True)

# %%
a.head(10)
# Out:
#                                                     Rating  sentiment
# Review
# it is too crowded with delivery executives all ...     3.5          1
# nice pocket friendly place. burgers and sandwic...     3.5          1
# well, all the time i have ordered here it has b...     3.5          1
# chocolate truffle is great here!ferrerro rocher...     3.5          1
# ks bakers , known for its food in bakery items....     3.5          1
# ordered chicken and cheese burger and egg puff ...     3.5          1
# the burger was just decent but complete value f...     3.5          1
# it is a good option but the bread they use for ...     3.5          1
# neat and clean ambiance. small place but it is ...     3.5          1
# komatose on a sunday night is the perfect place...     3.5          1

# %% [markdown]
# ###Remove multiple spaces

# %%
sent_df['Review']=sent_df['Review'].apply(lambda x: " ".join(x.split()))

# %%
sent_df
# Out:
#                                                  Review  Rating  sentiment
# 0     the ambience was good, food was quite good . h...     5.0          1
# 1     ambience is too good for a pleasant evening. s...     5.0          1
# 2     a must try.. great food great ambience. thnx f...     5.0          1
# 3     soumen das and arun was a great guy. only beca...     5.0          1
# 4     food is good.we ordered kodi drumsticks and ba...     5.0          1
# ...                                                 ...     ...        ...
# 9950  this place has never disappointed us.. the foo...     4.5          1
# 9951  bad rating is mainly because of "chicken bone ...     1.5          0
# 9952  i personally love and prefer chinese food. had...     4.0          1
# 9953  checked in here to try some delicious chinese ...     3.5          1
# 9954  one of the best pizzas to try. it served with ...     5.0          1
#
# [9955 rows x 3 columns]

# %% [markdown]
# ###Remove punctuations or special char

# %%
import string

# %%
def text_process(msg):
    nopunc =[char for char in msg if char not in string.punctuation]
    nopunc=''.join(nopunc)
    return nopunc

# %%
sent_df['Review'] = sent_df['Review'].apply(text_process)

# %%
sent_df.head()
# Out:
#                                               Review  Rating  sentiment
# 0  the ambience was good food was quite good  had...     5.0          1
# 1  ambience is too good for a pleasant evening se...     5.0          1
# 2  a must try great food great ambience thnx for ...     5.0          1
# 3  soumen das and arun was a great guy only becau...     5.0          1
# 4  food is goodwe ordered kodi drumsticks and bas...     5.0          1

# %% [markdown]
# ###Remove stop words

# %%
import spacy

# %%
#loading the english language small model of spacy
en = spacy.load('en_core_web_sm')
sw_spacy = en.Defaults.stop_words
print('There are :',len(sw_spacy) ,'stop words in nltk')
# Out:
# There are : 326 stop words in nltk

# %%
list(sw_spacy)[0:10]
# Out:
# ['anyway',
#  'thereby',
#  'have',
#  'indeed',
#  'made',
#  'few',
#  "n't",
#  'already',
#  'otherwise',
#  'through']

# %%
sent_df['Review']=sent_df['Review'].apply(lambda x:' '.join([i for i in x.split() if i not in sw_spacy]))

# %%
sent_df.head()
# Out:
#                                               Review  Rating  sentiment
# 0  ambience good food good saturday lunch cost ef...     5.0          1
# 1  ambience good pleasant evening service prompt ...     5.0          1
# 2  try great food great ambience thnx service pra...     5.0          1
# 3  soumen das arun great guy behavior sincerety g...     5.0          1
# 4  food goodwe ordered kodi drumsticks basket mut...     5.0          1

# %% [markdown]
# ###Converting words to root form

# %%
#download small spacy model
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 7.7 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.62.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.8.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.6.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.5.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
def lemmatization_(sentence):
    doc = nlp(sentence)
    l=list()
    for word in doc:
        
        l.append(word.lemma_)

    return ' '.join(l)

# %%
sent_df['Review']=sent_df['Review'].apply(lambda x:lemmatization_(x))

# %%
sent_df.head()
# Out:
#                                               Review  Rating  sentiment
# 0  ambience good food good saturday lunch cost ef...     5.0          1
# 1  ambience good pleasant evening service prompt ...     5.0          1
# 2  try great food great ambience thnx service pra...     5.0          1
# 3  soumen das arun great guy behavior sincerety g...     5.0          1
# 4  food goodwe order kodi drumstick basket mutton...     5.0          1

# %%
' '.join(sent_df['Review'])
# Out:
# 'ambience good food good saturday lunch cost effective good place sate brunch chill friend parentswaiter souman da courteous helpful ambience good pleasant evening service prompt food good good experience souman da kudos service try great food great ambience thnx service pradeep subroto personal recommendation penne alfredo pasta music background amazing soumen das arun great guy behavior sincerety good food course like visit place food goodwe order kodi drumstick basket mutton biryani good thank pradeep serve enjoy ambience good ambiance good service good food apradeecp subro best servicefood good papiya good hostess ur caption good 4star restaurant nice place ambience different food order tasty service gud worth visit reasonable visit place read review finally visit placeambience good come food crispy corn nice tawa fish ok basket biryani disappoint biryani ok flattering claim staff polite prompt especially pradeep suman excellent food specially like spicy food courteous staff shubro pradeep papiya give excellent service corporate team dinner overall great team dinners party come birthday treat close friend perfect place treat like hospitable cooperative staff food delicious ambience good music light chili honey lotus stem try special mention papiya take good care service great food awesome service staff manab papiya courteous attentive like come frequently place good ambience amazing food good service friendly staff pradeep papiya shuvro definitely visit love design menu card food good soup expect starter order honey chilli lotus stem try vegan ppl service great frequent visit papiya know experience food impressive food good telangana kodiak fry trymutton biriyani goodpapiya help choose good dish attend wellmust visit order corn cheese ball manchow soup paneer shashlik sizzler sizzler stale paneer smell waiter impolite accept mistake go food ambience fantastic waiter manav maji quick service cheese ball try starter scrumptious come lunch food good tasty try buffet item veg nonveg tastythe ambience service good staff courteousshubhamtraveltaleswordpresscom good thing place food favorite dish definitely alfredo pasta item good service behavior staff topnotch attend mr soumen da extremely polite definitely visit soon polite friendly staff nice ambience good spread menu drink awesome service good manav look forward see food good vegetarian item include paneer mushroom kofta additionally service papiya shuvro good beautiful cozy classy time place truly recommend special day 15 percent corporate discount treat cotorie burn hole ur pocket interior will love vibe menu honey chilli lotus stem basket biryani sizzle brownie favourite love tomato basil shorba different creamy standard restaurant -PRON- definitely make visit flavours special mention papiya hostess evening excellent service good expensive come taste rate 3 5 click well picture wen visit night 🤣 🤭 good day time pic service good fast people polite behave manav pradeep good hope behave way farewell feast recently enjoy good management boy give complimentary food happyfood perfect dessert starter wonderful excellent experience mouthwatere food good ambience place hyderabad serve shubhro papiya awesome behaviour enjoyable evening friend place good 5 live music superb beautiful voice food nice n love lightningentrance nice sonalin great voice visit place fan food good 5 star live music lighten awesome hear voiceshe beautiful amazing voice love voice way sings fan sonalin priyadarshini good place visit food nice sonalin good singer city beautiful face beautiful face visit place beautiful live music love love food good lightning food descent desert option goodstarrer tastyone bad experience ee wait time book table prior time short review decent bread starter bad shaam savera little screw daal makhni oneoff casebetter ambience night importantly good quantityi want 25 option extensiveambience well night friend day like prefer ambience nightfood order hara bhara kebab shaam savera  ...

# %%
words=' '.join(sent_df['Review'])
words_df=pd.Series(words)

# %%
word=' '.join(sent_df['Review']).split()
words_df=pd.Series(word)

# %%
words_df.head()
# Out:
# 0    ambience
# 1        good
# 2        food
# 3        good
# 4    saturday
# dtype: object

# %%
#top 5 common words
top5=words_df.value_counts()[0:10]
top5
# Out:
# good       7721
# food       5898
# place      5810
# order      3455
# chicken    2907
# taste      2795
# service    2788
# try        1915
# time       1864
# great      1807
# dtype: int64

# %%
# to remove most frequent words
sent_df['Review']=sent_df['Review'].apply(lambda x:" ".join([i for i in x.split() if i not in top5]))

# %%
sent_df.head()
# Out:
#                                               Review  Rating  sentiment
# 0  ambience saturday lunch cost effective sate br...     5.0          1
# 1  ambience pleasant evening prompt experience so...     5.0          1
# 2  ambience thnx pradeep subroto personal recomme...     5.0          1
# 3  soumen das arun guy behavior sincerety course ...     5.0          1
# 4  goodwe kodi drumstick basket mutton biryani th...     5.0          1

# %%
top5=words_df.value_counts(ascending=True)[0:10000]
sent_df['Review']=sent_df['Review'].apply(lambda x:" ".join([i for i in x.split() if i not in top5]))

# %%
from wordcloud import WordCloud

# %%
plt.figure( figsize=(10,10) )
wc=WordCloud().generate(words)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# ###TfidfVectorizer

# %%
x = sent_df['Review']
y=sent_df['sentiment']

# %%
from sklearn.model_selection import train_test_split
msg_train,msg_test,label_train,label_test = train_test_split(x,y,test_size=0.2,stratify=sent_df['sentiment'])

# %%
label_test.value_counts()
# Out:
# 1    1263
# 0     728
# Name: sentiment, dtype: int64

# %%
label_train.value_counts()
# Out:
# 1    5053
# 0    2911
# Name: sentiment, dtype: int64

# %%
from sklearn.feature_extraction.text import  TfidfVectorizer

# %%
tfid_vectorizer = TfidfVectorizer("english")

# %%
vectorizer = TfidfVectorizer("english")
x_train= vectorizer.fit_transform(msg_train)
x_test=vectorizer.transform(msg_test)

# %%
train_array= x_train.toarray()
test_array = x_test.toarray()

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB().fit(train_array,label_train)

# %%
train_preds = model.predict(train_array)
test_preds = model.predict(test_array)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(label_train,train_preds))
print("\n")
print(classification_report(label_test,test_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75      2911
#            1       1.00      0.61      0.76      5053
#
#     accuracy                           0.76      7964
#    macro avg       0.80      0.81      0.76      7964
# weighted avg       0.85      0.76      0.76      7964
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.77      0.56       728
#            1       0.76      0.44      0.55      1263
#
#     accuracy                           0.56      1991
#    macro avg       0.60      0.60      0.56      1991
# weighted avg       0.64      0.56      0.56      1991

# %%
print(confusion_matrix(label_train,train_preds))
print(confusion_matrix(label_test,test_preds))
# Out:
# [[2911    0]
#  [1950 3103]]
# [[557 171]
#  [713 550]]

# %% [markdown]
# ###LogisticRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(fit_intercept=True, max_iter=10000)
clf.fit(train_array,label_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
train_preds = clf.predict(train_array)
test_preds = clf.predict(test_array)

# %%
print(classification_report(label_train,train_preds))
print("\n")
print(classification_report(label_test,test_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.78      0.85      2911
#            1       0.88      0.97      0.92      5053
#
#     accuracy                           0.90      7964
#    macro avg       0.91      0.87      0.89      7964
# weighted avg       0.90      0.90      0.90      7964
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.66      0.75       728
#            1       0.83      0.94      0.88      1263
#
#     accuracy                           0.84      1991
#    macro avg       0.84      0.80      0.81      1991
# weighted avg       0.84      0.84      0.83      1991

# %%
print(confusion_matrix(label_train,train_preds))
print(confusion_matrix(label_test,test_preds))
# Out:
# [[2260  651]
#  [ 160 4893]]
# [[ 479  249]
#  [  76 1187]]

# %%
 s = "This must not b3 delet3d, but the number at the end yes 13004411"

# %%
s = re.sub("^\d+\s|\s\d+\s|\s\d+$", " ", s)

# %%
s
# Out:
# 'This must not b3 delet3d, but the number at the end yes '

# %% [markdown]
# ###ZOMATO RESTAURANT CLUSTERING

# %%
all_cuisines = ', '.join(i for i in cuisines.tolist())
all_cuisines = list(set(all_cuisines.split(', ')))

# %%
df2['Cuisines'] = df2['Cuisines'].apply(lambda x : x.lower())

# %%
d=df2.copy()

# %%
d=d.loc[:,['Name','Cost','Cuisines']]

# %%
len(all_cuisines)
# Out:
# 44

# %%
any=pd.DataFrame(columns=all_cuisines)

# %%
any.head()
# Out:
# Empty DataFrame
# Columns: [goan, mediterranean, ice cream, wraps, beverages, seafood, italian, north indian, japanese, arabian, sushi, salad, mughlai, juices, pizza, south indian, chinese, momos, kebab, american, mithai, thai, indonesian, bbq, european, desserts, healthy food, bakery, north eastern, andhra, malaysian, cafe, modern indian, lebanese, hyderabadi, biryani, street food, burger, continental, finger food, mexican, spanish, fast food, asian]
# Index: []

# %%
cluster_df=pd.concat([d,any])

# %%
cluster_df
# Out:
#                                        Name   Cost  ... fast food asian
# 0                           Beyond Flavours    800  ...       NaN   NaN
# 1                                  Paradise    800  ...       NaN   NaN
# 2                                  Flechazo  1,300  ...       NaN   NaN
# 3            Shah Ghouse Hotel & Restaurant    800  ...       NaN   NaN
# 4                Over The Moon Brew Company  1,200  ...       NaN   NaN
# ..                                      ...    ...  ...       ...   ...
# 100                               IndiBlaze    600  ...       NaN   NaN
# 101                            Sweet Basket    200  ...       NaN   NaN
# 102                        Angaara Counts 3    500  ...       NaN   NaN
# 103                             Wich Please    250  ...       NaN   NaN
# 104  Republic Of Noodles - Lemon Tree Hotel  1,700  ...       NaN   NaN
#
# [105 rows x 47 columns]
